# %%
from src.api_client import OpenCorporatesClient

client = OpenCorporatesClient()

# %%
# Search for a company
results = client.search_companies("Nestle")
print(results['results']['companies'][0])

# Get full details
nestle = client.get_company("ch", "66000778662")  # Example company number in Switzerland
print(nestle)

# Get directors
directors = client.get_officers("ch", "66000778662")
print(directors)
